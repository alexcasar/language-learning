# %%
# !/usr/bin/env python3

#cd ~/Desktop/snet/gits/lang-learn-repo/alex_tests
#python waveify.py ~/Desktop/snet/gits/lang-learn-repo/alex_tests/data testname

import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import pylab
import sys  
import subprocess
import pywt as pywt

# %%
path = '~/Desktop/snet/gits/lang-learn-repo/alex_tests/data'
filename = 'bgpclear_first'

mode = pywt.Modes.smooth

doc = pd.read_csv(path+"/"+filename+"/"+filename+"_raw.csv")

# %%
def plot_signal_decomp(data, w, title):
    w = pywt.Wavelet(w)
    a = data
    ca = []
    cd = []
    for i in range(10):
        (a, d) = pywt.dwt(a, w, mode)
        ca.append(a)
        cd.append(d)
    
    ff = np.fft.fft(data)
    
    rec_a = []
    rec_d = []

    for i, coeff in enumerate(ca):
        coeff_list = [coeff, None] + [None] * i
        #print(coeff_list)
        rec_a.append(pywt.waverec(coeff_list, w))

    for i, coeff in enumerate(cd):
        coeff_list = [None, coeff] + [None] * i
        #print(coeff_list)
        rec_d.append(pywt.waverec(coeff_list, w))

    fig = plt.figure(figsize=(20,10))
    ax_main = fig.add_subplot(len(rec_a) + 2, 1, 1)
    ax_main.set_title(title)
    ax_main.plot(data)
    ax_main.set_xlim(0, len(data) - 1)
    
    ax = fig.add_subplot(len(rec_a) + 2, 1, 2)
    ax.plot(ff)
    ax.set_xlim(0, len(ff) - 1)

    for i, y in enumerate(rec_a):
        ax = fig.add_subplot(len(rec_a) + 2, 2, 5 + i * 2)
        ax.plot(y, 'r')
        ax.set_xlim(0, len(y) - 1)
        ax.set_ylabel("A%d" % (i + 1))

    for i, y in enumerate(rec_d):
        ax = fig.add_subplot(len(rec_d) + 2, 2, 6 + i * 2)
        ax.plot(y, 'g')
        ax.set_xlim(0, len(y) - 1)
        ax.set_ylabel("D%d" % (i + 1)) 
    return rec_a, rec_d

# %%
varnames = doc.columns
v = varnames[0]
#for v in varnames[:-1]:
item = list(doc['vrf__update-messages-received_spine4'])

a,b = plot_signal_decomp(item, 'db2', v)
# Out:
# /home/alexcasar/miniconda3/envs/ull/lib/python3.7/site-packages/numpy/core/numeric.py:538: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)

# %%
varnames = doc.columns
v = varnames[2]
#for v in varnames[:-1]:
item = list(doc[v])

a,b = plot_signal_decomp(item, 'db2', v)

# %%
varnames = doc.columns
v = varnames[3]
#for v in varnames[:-1]:
item = list(doc[v])

a,b = plot_signal_decomp(item, 'db2', v)

# %%
pylab.subplot(2,2,1)
pylab.plot(item)

# %%
varnames = doc.columns
v = varnames[10]
#for v in varnames[:-1]:
item = list(doc[v])

a,b = plot_signal_decomp(item, 'db2', v)

# %%
varnames = doc.columns
v = varnames[15]
#for v in varnames[:-1]:
item = list(doc[v])

a,b = plot_signal_decomp(item, 'db2', v)

# %%
varnames = doc.columns
v = varnames[20]
#for v in varnames[:-1]:
item = list(doc[v])

a,b = plot_signal_decomp(item, 'db2', v)

# %%
varnames = doc.columns
v = varnames[25]
#for v in varnames[:-1]:
item = list(doc[v])

a,b = plot_signal_decomp(item, 'db2', v)

# %%
varnames = doc.columns
v = varnames[30]
#for v in varnames[:-1]:
item = list(doc[v])

a,b = plot_signal_decomp(item, 'db2', v)

# %%
varnames = doc.columns
v = varnames[35]
#for v in varnames[:-1]:
item = list(doc[v])

a,b = plot_signal_decomp(item, 'db2', v)

# %%
varnames = doc.columns
v = varnames[40]
#for v in varnames[:-1]:
item = list(doc[v])

a,b = plot_signal_decomp(item, 'db2', v)

# %%
varnames = doc.columns
v = varnames[45]
#for v in varnames[:-1]:
item = list(doc[v])

a,b = plot_signal_decomp(item, 'db2', v)

# %%
varnames = doc.columns
v = varnames[50]
#for v in varnames[:-1]:
item = list(doc[v])

a,b = plot_signal_decomp(item, 'db2', v)
